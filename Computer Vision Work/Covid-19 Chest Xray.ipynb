# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in /usr/local/lib/python3.7/dist-packages (0.5.4)

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from IPython.display import FileLink
from imutils import paths
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np.random.seed(0)

import random
import shutil
import cv2
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip "/content/gdrive/My Drive/dataset.zip"

# %%
# !unzip "/content/gdrive/My Drive/Chest_xray_dataset.zip"

# %%
dataset_path = './Covid_dataset'
input_path = './dataset/Covid dataset'

# %%
# %%bash
# rm -rf Covid_dataset
# mkdir -p Covid_dataset/covid
# mkdir -p Covid_dataset/normal

# %%
samples = 25

# %%
# construct the path to the metadata CSV file and load it
csvPath = os.path.sep.join([input_path, "metadata.csv"])
df = pd.read_csv(csvPath)

# %%
# loop over the rows of the COVID-19 data frame
for (i, row) in df.iterrows():
    # if (1) the current case is not COVID-19 or (2) this is not
    # a 'PA' view, then ignore the row
    if row["finding"] != "COVID-19" or row["view"] != "PA":
        continue

    # build the path to the input image file
    imagePath = os.path.sep.join([input_path, "images", row["filename"]])

    # if the input image file does not exist (there are some errors in
    # the COVID-19 metadeta file), ignore the row
    if not os.path.exists(imagePath):
        continue

    # extract the filename from the image path and then construct the
    # path to the copied image file
    filename = row["filename"].split(os.path.sep)[-1]
    outputPath = os.path.sep.join([f"{dataset_path}/covid", filename])

    # copy the image
    shutil.copy2(imagePath, outputPath)

# %%
covid_images = list(paths.list_images(f"{dataset_path}/covid"))
covid_images
# Out:
# ['./Covid_dataset/covid/88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-22-day1-pa.png',
#  './Covid_dataset/covid/F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg',
#  './Covid_dataset/covid/extubation-8.jpg',
#  './Covid_dataset/covid/paving.jpg',
#  './Covid_dataset/covid/auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  './Covid_dataset/covid/F4341CE7-73C9-45C6-99C8-8567A5484B63.jpeg',
#  './Covid_dataset/covid/kjr-21-e25-g001-l-a.jpg',
#  './Covid_dataset/covid/6C94A287-C059-46A0-8600-AFB95F4727B7.jpeg',
#  './Covid_dataset/covid/1-s2.0-S1684118220300682-main.pdf-003-b2.png',
#  './Covid_dataset/covid/covid-19-pneumonia-35-1.jpg',
#  './Covid_dataset/covid/16663_1_1.jpg',
#  './Covid_dataset/covid/4-x-day1.jpg',
#  './Covid_dataset/covid/auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  './Covid_dataset/covid/covid-19-pneumonia-34.png',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2b.png',
#  './Covid_dataset/covid/58cb9263f16e94305c730685358e4e_jumbo.jpeg',
#  './Covid_dataset/covid/nCoV-radiol.2020200269.fig1-day7.jpeg',
#  './Covid_dataset/covid/2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg',
#  './Covid_dataset/covid/nejmoa2001191_f3-PA.jpeg',
#  './Covid_dataset/covid/88de9d8c39e946abd495b37cd07d89e5-6531-0.jpg',
#  './Covid_dataset/covid/gr1_lrg-a.jpg',
#  './Covid_dataset/covid/1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg',
#  './Covid_dataset/covid/covid-19-pneumonia-93.png',
#  './Covid_dataset/covid/covid-19-pneumonia-58-day-7.jpg',
#  './Covid_dataset/covid/1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg',
#  './Covid_dataset/covid/03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg',
#  './Covid_dataset/covid/all14238-fig-0001-m-b.jpg',
#  './Covid_dataset/covid/23E99E2E-447C-46E5-8EB2-D35D12473C39.png',
#  './Covid_dataset/covid/figure1-5e71be566aa8714a04de3386-98-left.jpeg',
#  './Covid_dataset/covid/covid-19-caso-70-1-PA.jpg',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-000-fig1a.png',
#  './Covid_dataset/covid/covid-19-pneumonia-8.jpg',
#  './Covid_dataset/covid/F2DE909F-E19C-4900-92F5-8F435B031AC6.jpeg',
#  './Covid_dataset/covid/covid-19-pneumonia-58-day-9.jpg',
#  './Covid_dataset/covid/7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg',
#  './Covid_dataset/covid/1-s2.0-S1684118220300608-main.pdf-001.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-bilateral.jpg',
#  './Covid_dataset/covid/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  './Covid_dataset/covid/1-s2.0-S1684118220300682-main.pdf-002-a1.png',
#  './Covid_dataset/covid/16708_1_1.jpg',
#  './Covid_dataset/covid/2-chest-filmc.jpg',
#  './Covid_dataset/covid/93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg',
#  './Covid_dataset/covid/all14238-fig-0001-m-c.jpg',
#  './Covid_dataset/covid/7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg',
#  './Covid_dataset/covid/fff49165-b22d-4bb4-b9d1-d5d62c52436c.annot.original.png',
#  './Covid_dataset/covid/radiol.2020200490.fig3.jpeg',
#  './Covid_dataset/covid/ryct.2020200034.fig2.jpeg',
#  './Covid_dataset/covid/85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg',
#  './Covid_dataset/covid/16654_2_1.jpg',
#  './Covid_dataset/covid/353889E0-A1E8-4F9E-A0B8-F24F36BCFBFB.jpeg',
#  './Covid_dataset/covid/B2D20576-00B7-4519-A415-72DE29C90C34.jpeg',
#  './Covid_dataset/covid/7-fatal-covid19.jpg',
#  './Covid_dataset/covid/ryct.2020200034.fig5-day7.jpeg',
#  './Covid_dataset/covid/31BA3780-2323-493F-8AED-62081B9C383B.jpeg',
#  './Covid_dataset/covid/lancet-case2b.jpg',
#  './Covid_dataset/covid/2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg',
#  './Covid_dataset/covid/16660_1_1.jpg',
#  './Covid_dataset/covid/gr1_lrg-b.jpg',
#  './Covid_dataset/covid/41591_2020_819_Fig1_HTML.webp-day5.png',
#  './Covid_dataset/covid/covid-19-pneumonia-20.jpg',
#  './Covid_dataset/covid/1-s2.0-S1684118220300608-main.pdf-002.jpg',
#  './Covid_dataset/covid/kjr-21-e24-g002-l-a.jpg',
#  './Covid_dataset/covid/extubation-1.jpg',
#  './Covid_dataset/covid/ryct.2020200034.fig5-day4.jpeg',
#  './Covid_dataset/covid/16708_4_1.jpg',
#  './Covid_dataset/covid/yxppt-2020-02-19_00-51-27_287214-day8.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-7-PA.jpg',
#  './Covid_dataset/covid/16708_5_1.jpg',
#  './Covid_dataset/covid/80446565-E090-4187-A031-9D3CEAA586C8.jpeg',
#  './Covid_dataset/covid/6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3a.png',
#  './Covid_dataset/covid/41591_2020_819_Fig1_HTML.webp-day10.png',
#  './Covid_dataset/covid/6b3bdbc31f65230b8cdcc3cef5f8ba8a-40ac-0.jpg',
#  './Covid_dataset/covid/nejmc2001573_f1b.jpeg',
#  './Covid_dataset/covid/auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  './Covid_dataset/covid/1-s2.0-S1684118220300682-main.pdf-002-a2.png',
#  './Covid_dataset/covid/ciaa199.pdf-001-a.png',
#  './Covid_dataset/covid/covid-19-pneumonia-evolution-over-a-week-1-day0-PA.jpg',
#  './Covid_dataset/covid/kjr-21-e24-g001-l-a.jpg',
#  './Covid_dataset/covid/E63574A7-4188-4C8D-8D17-9D67A18A1AFA.jpeg',
#  './Covid_dataset/covid/9C34AF49-E589-44D5-92D3-168B3B04E4A6.jpeg',
#  './Covid_dataset/covid/8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg',
#  './Covid_dataset/covid/4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg',
#  './Covid_dataset/covid/16672_1_1.jpg',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-000-fig1b.png',
#  './Covid_dataset/covid/covid-19-pneumonia-30-PA.jpg',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3b.png',
#  './Covid_dataset/covid/covid-19-pneumonia-67.jpeg',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-003-fig4a.png',
#  './Covid_dataset/covid/covid-19-pneumonia-12.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-20-pa-on-admission.jpg',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-003-fig4b.png',
#  './Covid_dataset/covid/covid-19-pneumonia-14-PA.png',
#  './Covid_dataset/covid/ryct.2020200034.fig5-day0.jpeg',
#  './Covid_dataset/covid/16664_1_1.jpg',
#  './Covid_dataset/covid/1-s2.0-S0140673620303706-fx1_lrg.jpg',
#  './Covid_dataset/covid/AR-1.jpg',
#  './Covid_dataset/covid/6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg',
#  './Covid_dataset/covid/nejmc2001573_f1a.jpeg',
#  './Covid_dataset/covid/figure1-5e75d0940b71e1b702629659-98-right.jpeg',
#  './Covid_dataset/covid/covid-19-pneumonia-mild.JPG',
#  './Covid_dataset/covid/ciaa199.pdf-001-b.png',
#  './Covid_dataset/covid/16660_2_1.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-19.jpg',
#  './Covid_dataset/covid/radiol.2020200274.fig3d.png',
#  './Covid_dataset/covid/AR-2.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-58-day-10.jpg',
#  './Covid_dataset/covid/extubation-4.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-58-day-3.jpg',
#  './Covid_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2a.png',
#  './Covid_dataset/covid/lancet-case2a.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-2.jpg',
#  './Covid_dataset/covid/CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg',
#  './Covid_dataset/covid/nejmoa2001191_f1-PA.jpeg',
#  './Covid_dataset/covid/FE9F9A5D-2830-46F9-851B-1FF4534959BE.jpeg',
#  './Covid_dataset/covid/01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg',
#  './Covid_dataset/covid/covid-19-pneumonia-38-pa.jpg',
#  './Covid_dataset/covid/ae6c954c0039de4b5edee53865ffee43-e6c8-0.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-22-day2-pa.png',
#  './Covid_dataset/covid/kjr-21-e24-g003-l-a.jpg',
#  './Covid_dataset/covid/53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg',
#  './Covid_dataset/covid/16654_4_1.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-44-day-0.jpeg',
#  './Covid_dataset/covid/covid-19-pneumonia-28.png',
#  './Covid_dataset/covid/covid-19-infection-exclusive-gastrointestinal-symptoms-pa.png',
#  './Covid_dataset/covid/nejmoa2001191_f4.jpeg',
#  './Covid_dataset/covid/extubation-13.jpg',
#  './Covid_dataset/covid/16654_1_1.png',
#  './Covid_dataset/covid/16669_3_1.jpeg',
#  './Covid_dataset/covid/16669_1_1.jpeg',
#  './Covid_dataset/covid/1-s2.0-S1684118220300682-main.pdf-003-b1.png',
#  './Covid_dataset/covid/covid-19-pneumonia-15-PA.jpg',
#  './Covid_dataset/covid/nejmoa2001191_f5-PA.jpeg',
#  './Covid_dataset/covid/9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg',
#  './Covid_dataset/covid/16660_3_1.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-53.jpg',
#  './Covid_dataset/covid/16660_4_1.jpg',
#  './Covid_dataset/covid/covid-19-pneumonia-35-2.jpg',
#  './Covid_dataset/covid/ryct.2020200028.fig1a.jpeg',
#  './Covid_dataset/covid/ciaa199.pdf-001-c.png']

# %%
normal_dataset_path ='./Chest_xray_dataset'

# %%
basePath = os.path.sep.join([normal_dataset_path, "train", "NORMAL"])
imagePaths = list(paths.list_images(basePath))

# randomly sample the image paths
random.seed(42)
random.shuffle(imagePaths)
imagePaths = imagePaths[:samples]

# loop over the image paths
for (i, imagePath) in enumerate(imagePaths):
    # extract the filename from the image path and then construct the
    # path to the copied image file
    filename = imagePath.split(os.path.sep)[-1]
    outputPath = os.path.sep.join([f"{dataset_path}/normal", filename])

    # copy the image

    shutil.copy2(imagePath, outputPath)

# %%
df.finding.unique()
# Out:
# array(['COVID-19', 'ARDS', 'SARS', 'Pneumocystis', 'Streptococcus',
#        'No Finding', 'Chlamydophila', 'E.Coli', 'COVID-19, ARDS',
#        'Klebsiella', 'Legionella'], dtype=object)

# %%
df1 = df[df['finding'] == 'COVID-19, ARDS']

# %%
df1.head()
# Out:
#      patientid  ...  Unnamed: 28
# 183         96  ...          NaN
# 184         96  ...          NaN
# 185         96  ...          NaN
# 186         97  ...          NaN
# 187         97  ...          NaN
#
# [5 rows x 29 columns]

# %%
df1.shape
# Out:
# (12, 29)

# %%
normal_images = list(paths.list_images(f"{dataset_path}/normal"))
covid_images = list(paths.list_images(f"{dataset_path}/covid"))

# %%
plots_from_files(normal_images, rows=5, maintitle="Normal X-ray images")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-3f31d31fb842> in <module>()
# ----> 1 plots_from_files(normal_images, rows=5, maintitle="Normal X-ray images")
#
# NameError: name 'plots_from_files' is not defined

# %%
# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images

print("[INFO] loading images...")
imagePaths = list(paths.list_images(dataset_path))

data = []
labels = []

# loop over the image paths
for imagePath in imagePaths:
    # extract the class label from the filename
    label = imagePath.split(os.path.sep)[-2]
    # load the image, swap color channels, and resize it to be a fixed
    # 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.IMREAD_GRAYSCALE)
    image = cv2.resize(image, (224, 224))
    # update the data and labels lists, respectively
    image_np = (image).flatten()
    data.append(image_np)
    labels.append(label)
    
# convert the data and labels to NumPy arrays while scaling the pixel
# intensities to the range [0, 1]
data_train = np.array(data) / 255
labels_train = np.array(labels)
# Out:
# [INFO] loading images...

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels_train_y = lb.fit_transform(labels_train)
labels_train_cat = to_categorical(labels_train_y)

# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing

(X_train, X_test, y_train, y_test) = train_test_split(data, labels, test_size=0.20, stratify=labels, random_state=42)

# %%
X_train
# Out:
# [array([  0,   0,   0, ..., 153, 153, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([149, 149, 149, ...,  33,  33, 255], dtype=uint8),
#  array([ 46,  46,  46, ..., 111, 111, 255], dtype=uint8),
#  array([  6,   6,   6, ...,   6,   6, 255], dtype=uint8),
#  array([  0,   0,   0, ...,  11,  11, 255], dtype=uint8),
#  array([  1,   1,   1, ...,   1,   1, 255], dtype=uint8),
#  array([221, 221, 221, ..., 217, 217, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([133, 129, 128, ...,  33,  35, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 59,  56,  58, ...,  56,  58, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  9,   9,   9, ..., 162, 162, 255], dtype=uint8),
#  array([ 26,  25,  29, ...,  37,  37, 255], dtype=uint8),
#  array([104, 104, 104, ...,  46,  46, 255], dtype=uint8),
#  array([ 95,  95,  95, ..., 120, 120, 255], dtype=uint8),
#  array([177, 177, 177, ...,  46,  46, 255], dtype=uint8),
#  array([210, 212, 212, ...,  58,  58, 255], dtype=uint8),
#  array([  1,   1,   1, ...,   1,   1, 255], dtype=uint8),
#  array([255, 255, 255, ...,  17,  17, 255], dtype=uint8),
#  array([ 74,  74,  74, ..., 181, 181, 255], dtype=uint8),
#  array([127, 127, 127, ..., 134, 134, 255], dtype=uint8),
#  array([ 12,  12,  12, ...,   7,   7, 255], dtype=uint8),
#  array([ 19,  19,  19, ..., 145, 145, 255], dtype=uint8),
#  array([  1,   1,   1, ...,  30,  30, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([108, 108, 108, ...,  23,  23, 255], dtype=uint8),
#  array([  1,   1,   1, ..., 142, 144, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 96,  96,  96, ...,  85,  85, 255], dtype=uint8),
#  array([ 20,  23,  27, ...,  50,  54, 255], dtype=uint8),
#  array([ 52,  52,  52, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,  47,  47, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  1,   1,   1, ..., 237, 237, 255], dtype=uint8),
#  array([ 29,  24,  25, ..., 210, 210, 255], dtype=uint8),
#  array([  1,   1,   1, ...,  38,   6, 255], dtype=uint8),
#  array([111, 111, 111, ...,   0,   0, 255], dtype=uint8),
#  array([ 20,  20,  20, ..., 202, 202, 255], dtype=uint8),
#  array([ 50,  31,  10, ..., 154, 154, 255], dtype=uint8),
#  array([158, 158, 158, ...,  26,  26, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 17,  17,  17, ..., 125, 125, 255], dtype=uint8),
#  array([ 53,  53,  53, ..., 161, 161, 255], dtype=uint8),
#  array([  1,   1,   1, ...,  73,  73, 255], dtype=uint8),
#  array([ 47,  47,  47, ...,  42,  16, 255], dtype=uint8),
#  array([ 22,  22,  23, ...,  73,  76, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 12,  12,  12, ...,  25,  25, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 100, 100, 255], dtype=uint8),
#  array([  6,   6,   6, ...,   5,   5, 255], dtype=uint8),
#  array([ 33,  33,  33, ..., 155, 155, 255], dtype=uint8),
#  array([  1,   1,   1, ..., 156, 156, 255], dtype=uint8),
#  array([108, 108, 108, ...,   0,   0, 255], dtype=uint8),
#  array([104, 104, 104, ..., 199, 199, 255], dtype=uint8),
#  array([ 38,  38,  38, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,  24,  24, 255], dtype=uint8),
#  array([ 55,  52,  54, ...,  52,  54, 255], dtype=uint8),
#  array([  0,   0,   0, ...,  44,  44, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 131, 131, 255], dtype=uint8),
#  array([ 51,  51,  51, ..., 151, 151, 255], dtype=uint8),
#  array([  2,   2,   2, ...,  91,  87, 255], dtype=uint8),
#  array([190, 190, 190, ...,  63,  63, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 37,  37,  37, ...,   0,   0, 255], dtype=uint8),
#  array([118, 118, 118, ...,  17,  17, 255], dtype=uint8),
#  array([  1,   1,   1, ...,   1,   1, 255], dtype=uint8),
#  array([ 19,  19,  19, ...,  17,  17, 255], dtype=uint8),
#  array([  6,   6,   6, ...,  14,  14, 255], dtype=uint8),
#  array([  7,   7,   7, ...,   4,   4, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 175, 175, 255], dtype=uint8),
#  array([253, 253, 253, ..., 254, 254, 255], dtype=uint8),
#  array([ 91,  91,  91, ...,  22,  22, 255], dtype=uint8),
#  array([ 43,  42,  44, ...,  99,  99, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 157, 157, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 55,  55,  55, ...,   0,   0, 255], dtype=uint8),
#  array([ 62,  62,  62, ..., 125, 125, 255], dtype=uint8),
#  array([ 17,  17,  17, ...,  76,  78, 255], dtype=uint8),
#  array([  7,   7,   7, ...,   7,   7, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([255, 255, 255, ...,   0,   0, 255], dtype=uint8),
#  array([ 70,  70,  70, ...,  51,  51, 255], dtype=uint8),
#  array([  4,   4,   4, ..., 124, 124, 255], dtype=uint8),
#  array([ 12,   9,   5, ..., 167, 167, 255], dtype=uint8),
#  array([ 11,  11,  11, ..., 103, 103, 255], dtype=uint8),
#  array([  5,   5,   5, ...,  35,  35, 255], dtype=uint8),
#  array([185, 183, 182, ...,  13,  30, 255], dtype=uint8),
#  array([ 14,  14,  14, ...,  55,  55, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 97,  97,  97, ...,  29,  29, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 163, 164, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  2,   1,   3, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 130, 130, 255], dtype=uint8),
#  array([116, 116, 116, ...,   8,   8, 255], dtype=uint8),
#  array([184, 184, 184, ...,   1,   1, 255], dtype=uint8),
#  array([  3,   3,   1, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  4,   0,   0, ...,   1,   1, 255], dtype=uint8),
#  array([  0,   0,   0, ...,  32,  32, 255], dtype=uint8),
#  array([ 61,  61,  61, ..., 131, 131, 255], dtype=uint8),
#  array([ 59,  56,  58, ...,  57,  60, 255], dtype=uint8),
#  array([  8,   8,   8, ..., 117, 117, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([226, 226, 226, ..., 226, 226, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([166, 166, 166, ..., 149, 149, 255], dtype=uint8),
#  array([254, 254, 254, ..., 103, 102, 255], dtype=uint8),
#  array([193, 193, 193, ...,  57,  57, 255], dtype=uint8),
#  array([  2,   2,   2, ..., 231, 231, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,  41,  41, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 206, 206, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  1,   1,   1, ..., 194, 194, 255], dtype=uint8),
#  array([155, 155, 155, ...,   0,   0, 255], dtype=uint8),
#  array([  4,   4,   4, ...,   0,   0, 255], dtype=uint8),
#  array([152, 152, 152, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   9,   9, 255], dtype=uint8),
#  array([ 47,  24,   4, ..., 162, 160, 255], dtype=uint8),
#  array([  0,   0,   0, ...,  86,  86, 255], dtype=uint8),
#  array([  4,   4,   4, ...,   4,   6, 255], dtype=uint8),
#  array([ 46,  46,  46, ...,  11,  11, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 139, 139, 255], dtype=uint8),
#  array([ 17,  17,  17, ...,  52,  52, 255], dtype=uint8),
#  array([211, 212, 212, ...,  69,  68, 255], dtype=uint8)]

# %%
X_test
# Out:
# [array([ 45,  45,  45, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 47,  47,  47, ...,   0,   0, 255], dtype=uint8),
#  array([ 89,  46,   6, ...,  48,  44, 255], dtype=uint8),
#  array([  1,   1,   1, ...,  53,  54, 255], dtype=uint8),
#  array([ 79,  79,  79, ...,   3,   3, 255], dtype=uint8),
#  array([ 90,  90,  90, ..., 114, 114, 255], dtype=uint8),
#  array([ 50,  41,  32, ...,  44,  34, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([ 87,  87,  87, ...,   1,   1, 255], dtype=uint8),
#  array([ 15,  15,  15, ...,  39,  39, 255], dtype=uint8),
#  array([179, 179, 179, ..., 122, 122, 255], dtype=uint8),
#  array([ 77,  77,  77, ..., 133, 133, 255], dtype=uint8),
#  array([ 86,  86,  86, ...,   0,   0, 255], dtype=uint8),
#  array([133, 133, 133, ..., 254, 254, 255], dtype=uint8),
#  array([ 12,  12,  12, ...,  39,  39, 255], dtype=uint8),
#  array([  9,   4,   5, ..., 248, 244, 255], dtype=uint8),
#  array([ 17,  17,  17, ...,   0,   0, 255], dtype=uint8),
#  array([252, 252, 252, ...,  97,  96, 255], dtype=uint8),
#  array([  2,   2,   2, ..., 162, 162, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 136, 136, 255], dtype=uint8),
#  array([ 51,  82,  97, ..., 217, 217, 255], dtype=uint8),
#  array([ 20,  20,  20, ...,  16,  16, 255], dtype=uint8),
#  array([ 85,  85,  85, ...,   0,   0, 255], dtype=uint8),
#  array([ 63,  63,  63, ...,  81,  81, 255], dtype=uint8),
#  array([240, 240, 240, ..., 116, 115, 255], dtype=uint8),
#  array([ 17,  17,  17, ...,  12,  12, 255], dtype=uint8),
#  array([151, 144, 125, ...,   0,   0, 255], dtype=uint8),
#  array([ 71,  69,  68, ...,  65,  65, 255], dtype=uint8),
#  array([ 38,  38,  38, ...,   0,   0, 255], dtype=uint8),
#  array([169, 169, 169, ...,   0,   0, 255], dtype=uint8),
#  array([  0,   0,   0, ...,   0,   0, 255], dtype=uint8),
#  array([  4,   0,   0, ..., 250, 250, 255], dtype=uint8),
#  array([  0,   0,   0, ..., 144, 140, 255], dtype=uint8)]

# %%
y_train
# Out:
# ['covid',
#  'normal',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'normal',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid']

# %%
y_test
# Out:
# ['normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid',
#  'normal',
#  'covid',
#  'covid',
#  'covid']

# %%
np.unique(y_train)
# Out:
# array(['covid', 'normal'], dtype='<U6')

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.calibration import calibration_curve



# Create classifiers
lr = LogisticRegression(max_iter=10000)
gnb = GaussianNB()
svc = LinearSVC(C=1.0, max_iter=10000)
rfc = RandomForestClassifier()

# %%
LR_Model = lr.fit(X_train, y_train)

GNB_Model = gnb.fit(X_train, y_train)

SVC_Model = svc.fit(X_train, y_train)

RFC_Model = rfc.fit(X_train, y_train)

# %%
import pickle

with open('LR_model.pkl', 'wb') as f1:
    pickle.dump(LR_Model,f1)
    f1.close()

with open('GNB_model.pkl', 'wb') as f2:
    pickle.dump(GNB_Model,f2)
    f2.close()

with open('SVM_model.pkl', 'wb') as f3:
    pickle.dump(SVC_Model,f3)
    f3.close()

with open('RF_model.pkl', 'wb') as f4:
    pickle.dump(RFC_Model,f4)
    f4.close()

# %%
from IPython.display import FileLink

FileLink(r'LR_model.pkl')
# Out:
# /content/LR_model.pkl

# %%
FileLink(r'GNB_model.pkl')
# Out:
# /content/GNB_model.pkl

# %%
FileLink(r'SVM_model.pkl')
# Out:
# /content/SVM_model.pkl

# %%
FileLink(r'RF_model.pkl')
# Out:
# /content/RF_model.pkl

# %%
from sklearn.metrics import accuracy_score


LR_y_pred = LR_Model.predict(X_test)
GNB_y_pred = GNB_Model.predict(X_test)
SVC_y_pred = SVC_Model.predict(X_test)
RFC_y_pred = RFC_Model.predict(X_test)


# accuracy_score(y_true, y_pred)

# %%
LR_acc_sc = accuracy_score(y_test, LR_y_pred)
LR_acc_sc
# Out:
# 1.0

# %%
GNB_acc_sc = accuracy_score(y_test, GNB_y_pred)
GNB_acc_sc
# Out:
# 0.9411764705882353

# %%
SVC_acc_sc = accuracy_score(y_test, SVC_y_pred)
SVC_acc_sc
# Out:
# 1.0

# %%
RFC_acc_sc = accuracy_score(y_test, RFC_y_pred)
RFC_acc_sc
# Out:
# 0.9411764705882353

# %%
print('LogisticRegression score: %f' % LR_Model.score(X_test, y_test))
print('Naive Bayes score: %f' % GNB_Model.score(X_test, y_test))
print('SVM score: %f' % SVC_Model.score(X_test, y_test))
print('Random Forest score: %f' % RFC_Model.score(X_test, y_test))
# Out:
# LogisticRegression score: 1.000000
# Naive Bayes score: 0.941176
# SVM score: 1.000000
# Random Forest score: 0.941176

# %%
test_image_path ="./Covid_dataset"
image = cv2.imread(imagePath)
image = cv2.cvtColor(image, cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image, (224, 224))
# update the data and labels lists, respectively
image_np = (image).flatten()
test_img=[]
test_img_label=[]
test_img.append(image_np)
test_img_label.append('Covid')

# %%
LR_y_pred = LR_Model.predict(test_img)
GNB_y_pred = GNB_Model.predict(test_img)
SVC_y_pred = SVC_Model.predict(test_img)
RFC_y_pred = RFC_Model.predict(test_img)

# %%
LR_y_pred
# Out:
# array(['covid'], dtype='<U6')

# %%
GNB_y_pred
# Out:
# array(['covid'], dtype='<U6')

# %%
SVC_y_pred
# Out:
# array(['covid'], dtype='<U6')

# %%
RFC_y_pred
# Out:
# array(['normal'], dtype='<U6')
